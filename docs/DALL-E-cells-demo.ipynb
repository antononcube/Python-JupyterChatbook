# %% [markdown]
# ## Setup

# %%
import JupyterChatbook

# %%
# %load_ext JupyterChatbook

# %% [markdown]
# ------
#
# ## Image generation

# %%
# %%dalle -n 5 -s small
# Inkblot drawing of raccoon. Use white ink on black background.
# Out:
# <img src="data:image/png;base64,..." /><img src="data:image/png;base64,..." /><img src="data:image/png;base64,..." /><img src="data:image/png;base64,..." /><img src="data:image/png;base64,..." />

# %%
# %%dalle -n 2 -s medium
# Rube Goldberg machine with Quantum computer. Dark, cosmic background.
# Out:
# <img src="data:image/png;base64,..." /><img src="data:image/png;base64,..." />

# %% [markdown]
# ----
#
# ## Image edits

# %% [markdown]
# Here is the image to be edited below:
#
# ![](img/RandomMandala2.png)
#
# Here is the mask image:
#
# ![](img/RandomMandalaMask1.png)

# %%
# %%dalle --prompt "Add cosmic background."
# @img/RandomMandala2.png
# Out:
# <img src="data:image/png;base64,..." />

# %%
# %%dalle --prompt "Color in ivory color." --mask "img/RandomMandalaMask1.png"
# @img/RandomMandala2.png
# Out:
# <img src="data:image/png;base64,..." />
